# %% [markdown]
# ### Causal Inference Experiments

# %% [markdown]
# #### Mount Google Drive and change directory to the project folder
# Yours will be different, of course.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/dl4h_project/DynST/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/dl4h_project/DynST
# causal.ipynb            outputs/                            README.md
# config.yaml             poetry.lock                         README_new.md
# coxph_model.ipynb       project_causal.ipynb                results20230416.txt
# data/                   project_coxph_model.ipynb           run.py
# dl4hProjectSetup.ipynb  project_descriptive_notebook.ipynb  src/
# lightning_logs/         project_model.ipynb                 wandb/
# mimic3-survival/        project_preprocess.ipynb
# multirun/               pyproject.toml

# %% [markdown]
# #### Install some needed packages
# If you have not installed these in your current runtime before.
# You will need to restart the runtime after installation (Runtime > Restart Runtime)## change to the project code directory

# %%
# %pip install pytorch-lightning -q
# %pip install lifelines -q
# Install wandb
# %pip install wandb -qU

## now restart the runtime ##
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 45.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 68.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.4/409.4 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for autograd-gamma (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 37.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %%
# %cd /content/drive/MyDrive/dl4h_project/DynST/
# %ls
# Out:
# /content/drive/MyDrive/dl4h_project/DynST
# causal.ipynb            outputs/                            README.md
# config.yaml             poetry.lock                         README_new.md
# coxph_model.ipynb       project_causal.ipynb                results20230416.txt
# data/                   project_coxph_model.ipynb           run.py
# dl4hProjectSetup.ipynb  project_descriptive_notebook.ipynb  src/
# lightning_logs/         project_model.ipynb                 wandb/
# mimic3-survival/        project_preprocess.ipynb
# multirun/               pyproject.toml

# %% [markdown]
# #### Set up Weights and Biases

# %%
# Log in to your W&B account
# note, you may have to restart runtime after installing wandb
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# Install lifelines:
# lifelines is a complete survival analysis library, written in pure Python.
# https://lifelines.readthedocs.io/en/latest/

# %%
from src.dataset import Mimic3Dataset, padded_collate
from src.model import DST
import numpy as np
import torch
import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
import pandas as pd
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split

from lifelines import CoxPHFitter

wandb_logger = WandbLogger(project="dl4h_project", name="causal")
# Out:
# wandb: Currently logged in as: conlinm. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.1
# Run data is saved locally in <code>./wandb/run-20230505_162800-sdp0u88v</code>
# Syncing run <strong><a href='https://wandb.ai/conlinm/dl4h_project/runs/sdp0u88v' target="_blank">causal</a></strong> to <a href='https://wandb.ai/conlinm/dl4h_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/conlinm/dl4h_project' target="_blank">https://wandb.ai/conlinm/dl4h_project</a>
#  View run at <a href='https://wandb.ai/conlinm/dl4h_project/runs/sdp0u88v' target="_blank">https://wandb.ai/conlinm/dl4h_project/runs/sdp0u88v</a>

# %% [markdown]
# #### About
#
# Comparison of methods for computing ATE on restricted mean survival time. We used the following benchmarks:
# - Outcome Regression with DynST
# - Outcome Regression with Cox Model
# - Logistic IPW
# - AIPW (logistic propensity score model and DynST outcome model)

# %% [markdown]
# #### True ATE
# - $\tau = 8$: 0.265
# - $\tau = 12$: 0.572
# - $\tau = 16$: 0.946

# %% [markdown]
# #### Unadjusted Treatment Effect
# - $\tau = 8$: -0.237
# - $\tau = 12$: -0.539
# - $\tau = 16$: -0.933

# %% [markdown]
# ### Outcome Regression

# %%
dataset_treated = Mimic3Dataset(".", intervention=True, seed=30)
dataset_control = Mimic3Dataset(".", intervention=False, seed=30)

# %%
checkpoints = ["mimic3-survival/8la9a847/checkpoints/epoch=4-step=3320.ckpt",
              "mimic3-survival/8la9a847/checkpoints/epoch=4-step=3320.ckpt",
              "mimic3-survival/8la9a847/checkpoints/epoch=4-step=3320.ckpt",
              "mimic3-survival/8la9a847/checkpoints/epoch=4-step=3320.ckpt",
              "mimic3-survival/vciqrb3o/checkpoints/epoch=3-step=2656.ckpt",
              "mimic3-survival/8la9a847/checkpoints/epoch=4-step=3320.ckpt"]

# %%
collate_fn = lambda x: padded_collate(x, pad_index=-100, causal=True)
def get_predictions(model, dataset):
    dl = torch.utils.data.DataLoader(dataset, collate_fn=collate_fn, batch_size=96)
    predictor = pl.Trainer(accelerator = "gpu",
                           logger=wandb_logger)
    predictions = predictor.predict(model, dataloaders=dl)
    return torch.cat(predictions)

# %%
predict_treated = []
predict_control = []
seeds = [70,71,72,73,74,75]
for ix, c in enumerate(checkpoints):
    print(seeds[ix])
    model = DST.load_from_checkpoint(c)
    predict_treated.append(get_predictions(model, dataset_treated))
    predict_control.append(get_predictions(model, dataset_control))
# Out:
# 70
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, predict_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Predicting: 0it [00:00, ?it/s]
# /content/drive/MyDrive/dl4h_project/DynST/src/dataset.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item["codes"] = torch.tensor(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-8bfd466dcea7> in <cell line: 4>()
#       5     print(seeds[ix])
#       6     model = DST.load_from_checkpoint(c)
# ----> 7     predict_treated.append(get_predictions(model, dataset_treated))
#       8     predict_control.append(get_predictions(model, dataset_control))
#
# <ipython-input-6-0521c0c0ac8b> in get_predictions(model, dataset)
#       4     predictor = pl.Trainer(accelerator = "gpu",
#       5                            logger=wandb_logger)
# ----> 6     predictions = predictor.predict(model, dataloaders=dl)
#       7     return torch.cat(predictions)
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     803             model = _maybe_unwrap_optimized(model)
#     804             self.strategy._lightning_module = model
# --> 805         return call._call_and_handle_interrupt(
#     806             self, self._predict_impl, model, dataloaders, datamodule, return_predictions, ckpt_path
#     807         )
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#      43         else:
# ---> 44             return trainer_fn(*args, **kwargs)
#      45
#      46     except _TunerExitException:
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in _predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     845             self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     846         )
# --> 847         results = self._run(model, ckpt_path=ckpt_path)
#     848
#     849         assert self.state.stopped
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in _run(self, model, ckpt_path)
#     933         # RUN THE TRAINER
#     934         # ----------------------------
# --> 935         results = self._run_stage()
#     936
#     937         # ----------------------------
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in _run_stage(self)
#     971             return self._evaluation_loop.run()
#     972         if self.predicting:
# --> 973             return self.predict_loop.run()
#     974         if self.training:
#     975             with isolate_rng():
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/utilities.py in _decorator(self, *args, **kwargs)
#     175             context_manager = torch.no_grad
#     176         with context_manager():
# --> 177             return loop_run(self, *args, **kwargs)
#     178
#     179     return _decorator
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/prediction_loop.py in run(self)
#     110                 batch, batch_idx, dataloader_idx = next(data_fetcher)
#     111                 self.batch_progress.is_last_batch = data_fetcher.done
# --> 112                 self._predict_step(batch, batch_idx, dataloader_idx)
#     113             except StopIteration:
#     114                 # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/prediction_loop.py in _predict_step(self, batch, batch_idx, dataloader_idx)
#     226
#     227         # configure step_kwargs
# --> 228         predictions = call._call_strategy_hook(trainer, "predict_step", *step_kwargs.values())
#     229
#     230         self.batch_progress.increment_processed()
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/call.py in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     286
#     287     with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 288         output = fn(*args, **kwargs)
#     289
#     290     # restore current_fx when nested context
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/strategies/strategy.py in predict_step(self, *args, **kwargs)
#     394         with self.precision_plugin.predict_step_context():
#     395             assert isinstance(self.model, PredictStep)
# --> 396             return self.model.predict_step(*args, **kwargs)
#     397
#     398     def process_dataloader(self, dataloader: object) -> object:
#
# /content/drive/MyDrive/dl4h_project/DynST/src/model.py in predict_step(self, batch, batch_idx)
#     122     def predict_step(self, batch, batch_idx):
#     123         # returns estimated survival times
# --> 124         s_hat = self(batch)
#     125         mask = (batch["survival"] != self.pad)
#     126         return (s_hat * mask).sum(1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/MyDrive/dl4h_project/DynST/src/model.py in forward(self, batch)
#      61         # static features
#      62         x = self.embed_codes(batch["codes"]).unsqueeze(1)
# ---> 63         x = self.embed_static(
#      64             torch.cat([x, batch["static"].unsqueeze(1)], 2)
#      65         )
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (96x34 and 35x32)

# %% [markdown]
# #### Outcome Regression Estimate

# %%
taus = [8, 12, 16]
for i in range(len(predict_treated)):
    print(i)
    for tau in taus:    
        cutoff = torch.full(predict_treated[0].shape, tau)
        ey_x1 = torch.minimum(cutoff, predict_treated[i])
        ey_x0 = torch.minimum(cutoff, predict_control[i])
        print(ey_x1.mean() - ey_x0.mean())
# Out:
# 0
# tensor(0.1700)
# tensor(0.4110)
# tensor(0.6255)
# 1
# tensor(0.0733)
# tensor(0.3657)
# tensor(0.7719)
# 2
# tensor(0.1028)
# tensor(0.3217)
# tensor(0.6130)
# 3
# tensor(0.0900)
# tensor(0.3784)
# tensor(0.7639)
# 4
# tensor(0.1680)
# tensor(0.5457)
# tensor(0.8904)
# 5
# tensor(0.1077)
# tensor(0.4523)
# tensor(0.8688)

# %% [markdown]
# ### Cox Regression

# %%
df = pd.read_csv("data/mimic3_df_30.csv", index_col=[0,1])
df_sub = df.drop(
    columns=["treated", "control", "hazard", "q", "survival_prob", 
             "survives", "censored","corrected_survival", "critical", "first_failure",
            "baseline_hazard"]
)
df_flat = df_sub.groupby(level=0).mean()

# %%
df_flat["total_hours"] = df.groupby(level=0)["corrected_survival"].sum()
df_flat["uncensored"] = (df.groupby(level=0)["corrected_survival"].min() == 0).astype(int)

# %%
df_t = df_flat.copy()
df_t["A"] = 1
df_c = df_flat.copy()
df_c["A"] = 0

# %% [markdown]
# ### Cross validating...

# %%
def mae(df, y_hat):
    a = np.abs((df["total_hours"] - y_hat)[df["uncensored"].astype(bool)]).sum()
    b = np.maximum(np.zeros(df.shape[0]), df["total_hours"] - y_hat).sum()
    return (a + b) / df.shape[0]

# %%
predict_treated = []
predict_control = []
for seed in [71, 72, 73, 74, 75, 76, 77]:
    train, val = train_test_split(df_flat, train_size=0.8, random_state=seed)
    val_scores = []
    models = []
    for lam in [0, .1, .2,]:
        cph = CoxPHFitter(penalizer=lam)
        cph.fit(train, duration_col="total_hours", event_col="uncensored")
        models.append(cph)
        y_hat_val = cph.predict_expectation(val)
        val_scores.append(mae(val, y_hat_val))
    best_ix = np.argmin(val_scores)
    best_model = models[best_ix]
    predict_treated.append(best_model.predict_expectation(df_t))
    predict_control.append((best_model.predict_expectation(df_c)))

# %%
taus = [8, 12, 16]
for i in range(len(predict_treated)):
    print(i)
    for tau in taus:        
        cutoff = np.full(len(df_flat), tau)
        ey_x1 = np.minimum(cutoff, predict_treated[i])
        ey_x0 = np.minimum(cutoff, predict_control[i])
        print(ey_x1.mean() - ey_x0.mean())
# Out:
# 0
# 0.006990906215971648
# 0.04817908881326538
# 0.20784206957636364
# 1
# 0.005685950504813242
# 0.04674804763620877
# 0.1989215854282982
# 2
# 0.005243515192804082
# 0.04662786868173363
# 0.19497070653980053
# 3
# 0.0054282330270361
# 0.046855169459851354
# 0.1981455591943888
# 4
# 0.005037709638730625
# 0.0447034001044706
# 0.18694627135277742
# 5
# 0.0049232193938832935
# 0.04578574127161161
# 0.19545287258091193
# 6
# 0.003975559105430904
# 0.045807192170666866
# 0.18713421894600657

# %% [markdown]
# ### Propensity Score Weighing

# %%
df = pd.read_csv("data/mimic3_df_30.csv", index_col=[0,1])
# Out:
#                      gender  stay_length  hypertension  coronary_ath  \
# subject_id hours_in
# 4          0              0    -0.360949             0             0
#            1              0    -0.360949             0             0
#            2              0    -0.360949             0             0
#            3              0    -0.360949             0             0
#            4              0    -0.360949             0             0
#
#                      atrial_fib  hematocrit  hemoglobin  platelets  \
# subject_id hours_in
# 4          0                  0    0.076528   -0.111641  -0.187116
#            1                  0    0.076528   -0.111641  -0.187116
#            2                  0    0.076528   -0.111641  -0.187116
#            3                  0    0.076528   -0.111641  -0.187116
#            4                  0    0.076528   -0.111641  -0.187116
#
#                      mean blood pressure  treated  ...    A  baseline_hazard  \
# subject_id hours_in                                ...
# 4          0                    2.523323        1  ...  0.0         0.001000
#            1                    0.082396        1  ...  0.0         0.000779
#            2                    0.082396        1  ...  0.0         0.000607
#            3                   -0.490692        1  ...  0.0         0.000472
#            4                   -0.320892        1  ...  0.0         0.000368
#
#                        hazard  critical         q  survival_prob  survives  \
# subject_id hours_in
# 4          0         0.001013         0  0.998987       0.998097         1
#            1         0.000789         0  0.999211       0.999160         1
#            2         0.000614         0  0.999386       0.996084         1
#            3         0.000496         0  0.999504       0.997700         1
#            4         0.000378         0  0.999622       0.996546         1
#
#                      first_failure censored  corrected_survival
# subject_id hours_in
# 4          0                   NaN     True                   1
#            1                   NaN     True                   1
#            2                   NaN     True                   1
#            3                   NaN     True                   1
#            4                   NaN     True                   1
#
# [5 rows x 21 columns]

# %%
cols = ["A","hypertension", "coronary_ath", "atrial_fib" ]
df_flat = df[cols].groupby(level=0).head(1)

# %%
propensities = []
for seed in [71, 72, 73, 74, 75, 76, 77]:
    lr = LogisticRegressionCV(random_state=seed, max_iter=100)
    lr.fit(df_flat.drop(columns="A"), df_flat["A"])
    lr.score(df_flat.drop(columns="A"), df_flat["A"])
    pi_x = lr.predict_proba(df_flat.drop(columns="A"))[:, 1]
    propensities.append(pi_x)

# %%
def ipw(y, t, pi_x):
    p1 = (y * t) / pi_x
    p2 = ((1 - t) * y) / (1 - pi_x)
    return (p1 - p2).mean()

# %%
t = df.groupby(level=0)["A"].any().astype(int)
for pi_x in propensities:
    for tau in [8,12,16]:
        surv_restr = df.groupby(level=0)["corrected_survival"].head(tau)
        y = surv_restr.groupby(level=0).sum()
        print(ipw(y, t, pi_x))
    print("***")
# Out:
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***
# 0.5218639886321306
# 0.9275064793300295
# 1.3620698921976284
# ***

# %% [markdown]
# ### AIPW

# %%
def aipw(y, t, pi_x, ey_x1, ey_x0):
    b1 = ((t * y) / pi_x) - (((1 - t) * y) / (1 - pi_x))
    b2 = (t - pi_x) / (pi_x * (1 - pi_x)) * ((1 - pi_x) * ey_x1.numpy() + pi_x * ey_x0.numpy())
    return b1.mean() - b2.mean()

# %%
for i in range(len(predict_treated)):
    print(i)
    for tau in [8,12,16]:
        surv_restr = df.groupby(level=0)["corrected_survival"].head(tau)
        y = surv_restr.groupby(level=0).sum()
        cutoff = torch.full(predict_treated[0].shape, tau)
        ey_x1 = torch.minimum(cutoff, predict_treated[i])
        ey_x0 = torch.minimum(cutoff, predict_control[i])
        print(aipw(y, t, pi_x, ey_x1, ey_x0))
# Out:
# 0
# 0.2449780630071885
# 0.6446655469578944
# 1.1689455879817172
# 1
# 0.20984590972150602
# 0.5189298083180993
# 0.9954442420118628
# 2
# 0.22329082169686076
# 0.5758678432394009
# 1.0657333240910896
# 3
# 0.21811878943630775
# 0.53925737975217
# 1.011066912574107
# 4
# 0.23717831059358457
# 0.6600351872592145
# 1.196138547877693
# 5
# 0.2226971317555551
# 0.5723569840637329
# 1.0625096558344098
