# %% [markdown]
# ## Mount my Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Navigate to the folder I created already for the project

# %%
# %cd /content/drive/MyDrive/dl4h_project/
# %ls
# Out:
# /content/drive/MyDrive/dl4h_project
# dl4hProjectSetup.ipynb  DynST/

# %% [markdown]
# Clone my repo @ https://github.com/conlinm/DynST.git

# %%
# already done
#!git clone https://github.com/conlinm/DynST.git
# Out:
# Cloning into 'DynST'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 168 (delta 98), reused 156 (delta 93), pack-reused 0
# Receiving objects: 100% (168/168), 309.60 KiB | 6.59 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %% [markdown]
# ## Configure my google drive git repo to enable pushing changes

# %% [markdown]
# config variables
# I am actually pushing changes from my local machine, but this is how I would do it if I was using colab

# %% [markdown]
# Change into repo

# %%
# %cd DynST/
# Out:
# /content/drive/MyDrive/dl4h_project/DynST

# %% [markdown]
# add remote

# %%
# already done
# !git remote add origin https://{git_token}@github.com/{username}/{repository}
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://github.com/conlinm/DynST.git (fetch)
# origin	https://github.com/conlinm/DynST.git (push)

# %% [markdown]
# OK, I will see if I can push this later after changes and see if it works without the token?

# %% [markdown]
# ## Setup the data
# See the readme.md file
# - First I put the all_hourly_data.h5 into a folder data/
# - I did this manually using google drive, and it took several hours to load the nearly 8 gb of data
# - Then I ran the command to preprocess the data

# %% [markdown]
# Now run the preprocess script to generate the semisynthetic data

# %%
# !curl -sSL https://install.python-poetry.org | python3 -
# Out:
# Retrieving Poetry metadata
#
# # Welcome to Poetry!
#
# This will download and install the latest version of Poetry,
# a dependency and package manager for Python.
#
# It will add the `poetry` command to Poetry's bin directory, located at:
#
# /root/.local/bin
#
# You can uninstall at any time by executing this script with the --uninstall option,
# and these changes will be reverted.
#
# Installing Poetry (1.4.2)
# Installing Poetry (1.4.2): Creating environment
# Installing Poetry (1.4.2): Installing Poetry
# Installing Poetry (1.4.2): Creating script
# Installing Poetry (1.4.2): Done
#
# Poetry (1.4.2) is installed now. Great!
#
# To get started you need Poetry's bin directory (/root/.local/bin) in your `PATH`
# environment variable.
#
# Add `export PATH="/root/.local/bin:$PATH"` to your shell configuration file.
#
# Alternatively, you can call Poetry explicitly with `/root/.local/bin/poetry`.
#
# You can test that everything is set up by executing:
#
# `poetry --version`

# %%
# !/root/.local/bin/poetry install
# Out:
# Installing dependencies from lock file
#
# Package operations: 133 installs, 0 updates, 0 removals

# %%
# !pip install hydra-core==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.2 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=444b8d272769fb93a445e68180a833706b930b1ef8f8ef10c020d80d91c2d91e
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built antlr4-python3-runtime
# ...

# %%
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.6/718.6 kB 45.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 55.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 32.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 17.1 MB/s eta 0:00:00
# ...

# %%
# already done
# !python run.py preprocess.do=True
# Out:
# /content/drive/MyDrive/dl4h_project/DynST/run.py:11: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=".", config_name="config.yaml")
# /usr/local/lib/python3.9/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2023-04-13 18:45:22,894][src.preprocess][INFO] - Beginning pipeline
# [2023-04-13 18:45:24,985][src.preprocess][INFO] - Processing codes
# [2023-04-13 18:45:30,877][src.preprocess][INFO] - Processing vitals
# /content/drive/MyDrive/dl4h_project/DynST/src/preprocess.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Train the Model
# To launch a multirun of DynST sweeping over several hyperparameters, you can enter the following command:
# ```
# python run -m model.d_model=32,64 model.alpha=0,0.1,0.2
# ```

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# !python run -m model.d_model=32,64 model.alpha=0,0.1,0.2
# Out:
# python3: can't open file '/content/drive/MyDrive/dl4h_project/DynST/run': [Errno 2] No such file or directory
